# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/workspace/nabang1010/LBA_VAIPE/GNN/GNN_Drugnames_Extraction_from_Prescription/data_GNN/data_csv/VAIPE_P_TRAIN_0.csv')
df
# Out:
#     xmin  ymin  xmax  ymax                                             Object  \
# 0     58    28   113    58                                                1/1
# 1    153    60   208    76                                              LHANG
# 2    372    91   535   123                                 Số phiếu 1646/2019
# 3    626   100   688   118                                            3648383
# 4    260   122   508   152                                     TOA THUỐC BHYT
# 5    618   160   655   177                                                Nam
# 6    685   160   708   177                                                 Nữ
# 7    366   207   387   224                                                 35
# 8    436   207   468   225                                                208
# 9    509   207   560   225                                              07327
# 10   300   208   322   225                                                 35
# ...

# %%
# set value row idx
idx = df[df["label"] == "date"].index[0]
idx
df.loc[idx, "xmax"] = df.loc[idx, "xmax"] + 20

# %%
df
# Out:
#     xmin  ymin  xmax  ymax                                             Object  \
# 0     58    28   113    58                                                1/1
# 1    153    60   208    76                                              LHANG
# 2    372    91   535   123                                 Số phiếu 1646/2019
# 3    626   100   688   118                                            3648383
# 4    260   122   508   152                                     TOA THUỐC BHYT
# 5    618   160   655   177                                                Nam
# 6    685   160   708   177                                                 Nữ
# 7    366   207   387   224                                                 35
# 8    436   207   468   225                                                208
# 9    509   207   560   225                                              07327
# 10   300   208   322   225                                                 35
# ...
